# %%
import os
import pandas as pd
import numpy as np
import win32api
import time

# %%
#checks available drives. important that G: drive appears here.
drives = win32api.GetLogicalDriveStrings()
drives = drives.split('\000')[:-1]
print (drives)
# Out:
# ['C:\\', 'G:\\']

# %%
#declare full path where the files are saved
cwd = os.path.abspath('G:\\ALL\RETAIL TRADING PODS\SOUTH\Planning\FW21\sales_launch\sl_feedback') 
#declare sheet name. template must have data as the name of the sheet
my_sheet = "MAIN"

# %%
#checks files inside the folder
files = os.listdir(cwd) 
print(files)
# Out:
# ['ITALY FACTORY ASSORTMENT FW21.xlsx', 'Copia de 02_IBERIA_07_VIA MODA_RECTIFICADO.xlsx', 'assortFW21 APPAREL.xlsx', '02_IBERIA_06_PATRIMI_APPAREL - PROPUESTA PATRIMI.xlsx', '02_IBERIA_02_ANGEL BRAVO_APPAREL REVISADO.xlsx', 'LS EDERY FW21 Bordeaux centre.xlsx', 'ASSORTIMENT LSE LA SCOLA TAIEB.xlsx', '04_ITALY_01_PATRIMI_APPAREL - PROPUESTA - PATRIMI.xlsx', '01_FR_11_MELLOUL_APPAREL.xlsx', '02_IBERIA_01_ ADELINA FLORIDO_APPAREL.xlsx', '03_ITALY_01_GAMBARDELLA_APPAREL fw21.xlsx', 'FW21 02_IBERIA_00_GN1_APPAREL.cleaned.xlsx', '01_FR_04_CHICHA _APPAREL.xlsx', '02_IBERIA_05_GNG_APPAREL.xlsx', 'FALL21_02_IBERIA_04_GALCERAN_APPAREL_TOTAL.xlsx', '05_ITALY_01_VADALA_APPAREL.xlsx', 'assortiments.xlsx', 'Copie de FALL 2021 CHEMLA_APPAREL.xlsx', '02_IBERIA_03_CRYSTAL_APPAREL.xlsx', '01_FR_12_QUERE_APPAREL.xlsx', '01_FR_13_SANNA_APPAREL.xlsx', 'APPAREL FW 2021.xlsx', '20201218 assortiment groupe AVRIL.xlsx', '01_FR_09_GOMES_APPAREL.xlsx', 'Copie de 01_FR_06_DIAS_APPAREL.xlsx', '02_ITALY_01_DENIM LION_APPAREL.xlsx', '01_FR_02_BOURBOTTE_APPAREL.xlsx']

# %%
#initialize empty df
df = pd.DataFrame()
#initialize empty list to append resutls from below loop.
appended_data = []

# %%
#>>>>>>>>>>>>>>>>>>>>>>>>>>>>below loop will run 1-by-1 on all files saved in folder<<<<<<<<<<<<<<<<<<<
for file in files:
    
    #define name of the file >> import to current df
    full_file = cwd + "\\" + file
    df = pd.read_excel(full_file, sheet_name=my_sheet, ignore_index=True)
    
    #>>>>>>>>>>>>Next section cleans data (unwanted rows and columns)
    #drop all columns from sections we dont care about (eg. d, e,f, etc.)
    df=df.drop(df.filter(like='d',axis=1).columns,axis=1)
    df=df.drop(df.filter(like='e',axis=1).columns,axis=1)
    df=df.drop(df.filter(like='f',axis=1).columns,axis=1)
    df=df.drop(df.filter(like='g',axis=1).columns,axis=1)
    df=df.drop(df.filter(like='h',axis=1).columns,axis=1)
    df=df.drop(df.filter(like='x',axis=1).columns,axis=1)
     
    #renames first column called 'a' to pc9.
    df.rename(columns={'a': 'pc9'}, inplace=True)
    #other columns a1, a2, etc. had been created. this deletes all those unwanted columns
    df = df[df.columns.drop(list(df.filter(regex='a')))]
    #this deletes of all rows where pc9 is NA.
    df = df[df['pc9'].notna()]
    
    #at this stage, the df has generic column names, eg. 0, 1, 2, etc.
    #Below renames columns of dataframe to first row (which contains titles in the excel)
    df.columns = df.iloc[1]
    #This gets rid of first row (ie. title rows from excel), so only data remains in df
    df = df[2:]
    #renames column material to pc9. just to make code easier.
    df.rename(columns={'Material code': 'pc9'}, inplace=True)
    
    
    #>>>>>>>>>>>>>>this 1 line of magic unpivots the data :). amazing.
    df = df.melt(id_vars=['pc9'],var_name='key', value_name='selected')
    
    
    #>>>>> Next section creates mini dataframe 'new', to split key into separate columns (shipto and measure)
    # new data frame with split value columns 
    new = df["key"].str.split("|", n = 1, expand = True) 
    # making separate first name column from new data frame 
    df["ship_to"]= new[0] 
    # making separate last name column from new data frame 
    df["measure"]= new[1] 
    ##Add file name to df
    df["source_file"] = file
    # Dropping old Name columns 
    df.drop(columns =["key"], inplace = True) 
    
    #>>>>>>>> next section appends current df into the list. it will stack one file after another.
    appended_data.append(df)
    
    #>>>>>>>End of loop. It will repeat for every file in our folder.

# %%
#>>>>>>>> this converts list into a data frame with the same name. list ceases to exist.
appended_data = pd.concat(appended_data)

# %%
appended_data
# Out:
#               pc9 selected                 ship_to                  measure  \
# 0      29507-0031        1                10057504         OPTIONS_PROPOSAL
# 1      29507-0280        1                10057504         OPTIONS_PROPOSAL
# 2      29507-0548        1                10057504         OPTIONS_PROPOSAL
# 3      29507-0805        1                10057504         OPTIONS_PROPOSAL
# 4      29507-0839        1                10057504         OPTIONS_PROPOSAL
# 5      29507-0940        0                10057504         OPTIONS_PROPOSAL
# 6      29507-0994        0                10057504         OPTIONS_PROPOSAL
# 7      29507-1030        1                10057504         OPTIONS_PROPOSAL
# 8      29507-1083        0                10057504         OPTIONS_PROPOSAL
# 9      29507-1091        0                10057504         OPTIONS_PROPOSAL
# 10     29507-1094        0                10057504         OPTIONS_PROPOSAL
# 11     29507-1109        1                10057504         OPTIONS_PROPOSAL
# 12     05510-1097        0                10057504         OPTIONS_PROPOSAL
# 13     05510-1129        1                10057504         OPTIONS_PROPOSAL
# 14     05510-1134        0                10057504         OPTIONS_PROPOSAL
# 15     05510-1167        0                10057504         OPTIONS_PROPOSAL
# 16     05510-1168        1                10057504         OPTIONS_PROPOSAL
# 17     05510-1171        0                10057504         OPTIONS_PROPOSAL
# 18     05510-1176        1                10057504         OPTIONS_PROPOSAL
# 19     04511-1507        1                10057504         OPTIONS_PROPOSAL
# 20     04511-1786        1                10057504         OPTIONS_PROPOSAL
# 21     04511-4102        1                10057504         OPTIONS_PROPOSAL
# 22     04511-4579        0                10057504         OPTIONS_PROPOSAL
# 23     04511-4623        1                10057504         OPTIONS_PROPOSAL
# 24     04511-4759        1                10057504         OPTIONS_PROPOSAL
# 25     04511-5003        0                10057504         OPTIONS_PROPOSAL
# 26     04511-5076        0                10057504         OPTIONS_PROPOSAL
# 27     04511-5078        0                10057504         OPTIONS_PROPOSAL
# 28     04511-5081        0                10057504         OPTIONS_PROPOSAL
# 29     04511-5083        0                10057504         OPTIONS_PROPOSAL
# ...           ...      ...                     ...                      ...
# 13690  A0654-0000        0  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13691  A0654-0001        0  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13692  A0655-0000        1  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13693  A0655-0001        1  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13694  A0798-0001        0  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13695  A0799-0000        1  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13696  A0799-0002        0  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13697  A0890-0000        0  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13698  29944-0162        0  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13699  29945-0036        1  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13700  29945-0063        1  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13701  29945-0070        1  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13702  29945-0100        1  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13703  29945-0111        1  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13704  29945-0112        0  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13705  29945-0116        0  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13706  A0803-0000        0  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13707  A0804-0000        1  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13708  A0805-0000        0  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13709  A0811-0001        0  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13710  36137-0015        1  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13711  36137-0026        1  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13712  36137-0034        0  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13713  36137-0045        1  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13714  A0813-0000        0  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13715  A0821-0000        0  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13716  A1227-0000        1  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13717  27543-0004        0  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13718  86143-0005        0  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
# 13719  A1056-0000        0  LS Nimes Cap Costières  OPTIONS_CUSTOMER_REVIEW
#
#                               source_file
# 0      ITALY FACTORY ASSORTMENT FW21.xlsx
# 1      ITALY FACTORY ASSORTMENT FW21.xlsx
# 2      ITALY FACTORY ASSORTMENT FW21.xlsx
# 3      ITALY FACTORY ASSORTMENT FW21.xlsx
# 4      ITALY FACTORY ASSORTMENT FW21.xlsx
# 5      ITALY FACTORY ASSORTMENT FW21.xlsx
# 6      ITALY FACTORY ASSORTMENT FW21.xlsx
# 7      ITALY FACTORY ASSORTMENT FW21.xlsx
# 8      ITALY FACTORY ASSORTMENT FW21.xlsx
# 9      ITALY FACTORY ASSORTMENT FW21.xlsx
# 10     ITALY FACTORY ASSORTMENT FW21.xlsx
# 11     ITALY FACTORY ASSORTMENT FW21.xlsx
# 12     ITALY FACTORY ASSORTMENT FW21.xlsx
# 13     ITALY FACTORY ASSORTMENT FW21.xlsx
# 14     ITALY FACTORY ASSORTMENT FW21.xlsx
# 15     ITALY FACTORY ASSORTMENT FW21.xlsx
# 16     ITALY FACTORY ASSORTMENT FW21.xlsx
# 17     ITALY FACTORY ASSORTMENT FW21.xlsx
# 18     ITALY FACTORY ASSORTMENT FW21.xlsx
# 19     ITALY FACTORY ASSORTMENT FW21.xlsx
# 20     ITALY FACTORY ASSORTMENT FW21.xlsx
# 21     ITALY FACTORY ASSORTMENT FW21.xlsx
# 22     ITALY FACTORY ASSORTMENT FW21.xlsx
# 23     ITALY FACTORY ASSORTMENT FW21.xlsx
# 24     ITALY FACTORY ASSORTMENT FW21.xlsx
# 25     ITALY FACTORY ASSORTMENT FW21.xlsx
# 26     ITALY FACTORY ASSORTMENT FW21.xlsx
# 27     ITALY FACTORY ASSORTMENT FW21.xlsx
# 28     ITALY FACTORY ASSORTMENT FW21.xlsx
# 29     ITALY FACTORY ASSORTMENT FW21.xlsx
# ...                                   ...
# 13690     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13691     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13692     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13693     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13694     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13695     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13696     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13697     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13698     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13699     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13700     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13701     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13702     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13703     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13704     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13705     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13706     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13707     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13708     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13709     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13710     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13711     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13712     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13713     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13714     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13715     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13716     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13717     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13718     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 13719     01_FR_02_BOURBOTTE_APPAREL.xlsx
#
# [336140 rows x 5 columns]

# %%
timestr = time.strftime("%Y%m%d-%H%M%S")
file_name = "sl_output_"+timestr+".xlsx"
print (file_name)
# Out:
# sl_output_20201221-175348.xlsx

# %%
appended_data.to_excel(file_name)
