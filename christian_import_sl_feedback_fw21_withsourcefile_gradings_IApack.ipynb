# %%
import os
import pandas as pd
import numpy as np
import win32api
import time

# %%
#checks available drives. important that G: drive appears here.
drives = win32api.GetLogicalDriveStrings()
drives = drives.split('\000')[:-1]
print (drives)
# Out:
# ['C:\\', 'G:\\']

# %%
#declare full path where the files are saved
cwd = os.path.abspath('G:\\ALL\RETAIL TRADING PODS\SOUTH\Planning\FW21\sales_launch\sl_feedback') 
#declare sheet name. template must have data as the name of the sheet
my_sheet = "MAIN"

# %%
#checks files inside the folder
files = os.listdir(cwd) 
print(files)
# Out:
# ['ITALY FACTORY ASSORTMENT FW21.xlsx', 'Copia de 02_IBERIA_07_VIA MODA_RECTIFICADO.xlsx', 'assortFW21 APPAREL.xlsx', '02_IBERIA_06_PATRIMI_APPAREL - PROPUESTA PATRIMI.xlsx', '02_IBERIA_02_ANGEL BRAVO_APPAREL REVISADO.xlsx', 'LS EDERY FW21 Bordeaux centre.xlsx', 'ASSORTIMENT LSE LA SCOLA TAIEB.xlsx', '04_ITALY_01_PATRIMI_APPAREL - PROPUESTA - PATRIMI.xlsx', '01_FR_11_MELLOUL_APPAREL.xlsx', '02_IBERIA_01_ ADELINA FLORIDO_APPAREL.xlsx', '03_ITALY_01_GAMBARDELLA_APPAREL fw21.xlsx', 'FW21 02_IBERIA_00_GN1_APPAREL.cleaned.xlsx', '01_FR_04_CHICHA _APPAREL.xlsx', '02_IBERIA_05_GNG_APPAREL.xlsx', 'FALL21_02_IBERIA_04_GALCERAN_APPAREL_TOTAL.xlsx', '05_ITALY_01_VADALA_APPAREL.xlsx', 'assortiments.xlsx', 'Copie de FALL 2021 CHEMLA_APPAREL.xlsx', '02_IBERIA_03_CRYSTAL_APPAREL.xlsx', '01_FR_12_QUERE_APPAREL.xlsx', '01_FR_13_SANNA_APPAREL.xlsx', 'APPAREL FW 2021.xlsx', '20201218 assortiment groupe AVRIL.xlsx', '01_FR_09_GOMES_APPAREL.xlsx', 'Copie de 01_FR_06_DIAS_APPAREL.xlsx', '02_ITALY_01_DENIM LION_APPAREL.xlsx', '01_FR_02_BOURBOTTE_APPAREL.xlsx']

# %%
#initialize empty df
df = pd.DataFrame()
#initialize empty list to append resutls from below loop.
appended_data = []

# %%
#>>>>>>>>>>>>>>>>>>>>>>>>>>>>below loop will run 1-by-1 on all files saved in folder<<<<<<<<<<<<<<<<<<<
for file in files:
    
    #define name of the file >> import to current df
    full_file = cwd + "\\" + file
    df = pd.read_excel(full_file, sheet_name=my_sheet, ignore_index=True)
    
    #>>>>>>>>>>>>Next section cleans data (unwanted rows and columns)
    #drop all columns from sections we dont care about (eg. d, e,f, etc.)
    df=df.drop(df.filter(like='b',axis=1).columns,axis=1)
    df=df.drop(df.filter(like='d',axis=1).columns,axis=1)
    df=df.drop(df.filter(like='e',axis=1).columns,axis=1)
    df=df.drop(df.filter(like='f',axis=1).columns,axis=1)
    df=df.drop(df.filter(like='g',axis=1).columns,axis=1)
    df=df.drop(df.filter(like='h',axis=1).columns,axis=1)
    #df=df.drop(df.filter(like='x',axis=1).columns,axis=1)
     
    #renames first column called 'a' to pc9.
    df.rename(columns={'a': 'pc9'}, inplace=True)
    #other columns a1, a2, etc. had been created. this deletes all those unwanted columns
    df = df[df.columns.drop(list(df.filter(regex='a')))]
    #this deletes of all rows where pc9 is NA.
    df = df[df['pc9'].isna()]
    ##until here good
    
    #at this stage, the df has generic column names, eg. 0, 1, 2, etc.
    #Below renames columns of dataframe to first row (which contains titles in the excel)
    df.columns = df.iloc[0]
    #This gets rid of first row (ie. title rows from excel), so only data remains in df
    df = df[1:]
    #gets rid of nan column names
    df = df.loc[:, df.columns.notnull()]
    #renames column material to pc9. just to make code easier.
    df.rename(columns={'Key': 'store_attributes'}, inplace=True)
    
    
    #>>>>>>>>>>>>>>this 1 line of magic unpivots the data :). amazing.
    df = df.melt(id_vars=['store_attributes'],var_name='key', value_name='selected')
    
    
    #>>>>> Next section creates mini dataframe 'new', to split key into separate columns (shipto and measure)
    # new data frame with split value columns 
    new = df["key"].str.split("|", n = 1, expand = True) 
    # making separate first name column from new data frame 
    df["ship_to"]= new[0] 
    # making separate last name column from new data frame 
    df["measure"]= new[1] 
    ##Add file name to df
    df["source_file"] = file
    # Dropping old Name columns 
    df.drop(columns =["key"], inplace = True) 
    
    #>>>>>>>> next section appends current df into the list. it will stack one file after another.
    appended_data.append(df)
    
    #>>>>>>>End of loop. It will repeat for every file in our folder.

# %%
#>>>>>>>> this converts list into a data frame with the same name. list ceases to exist.
appended_data = pd.concat(appended_data)

# %%
appended_data
# Out:
#          store_attributes                   selected                 ship_to  \
# 0                 IA PACK                    IT_PLUS                10057504
# 1             Ship to Key                   10057504                10057504
# 2             Index Store                          1                10057504
# 3                 Partner                    CIPOLLA                10057504
# 4   Merch New Segmentaion                     NORMAL                10057504
# 5            Mens Grading                          M                10057504
# 6          Womens Grading                          M                10057504
# 7          SAP Store Name                   LS AOSTA                10057504
# 8                   TOTAL                        344                10057504
# 9                 IA PACK                    IT_PLUS                10053982
# 10            Ship to Key                   10053982                10053982
# 11            Index Store                          2                10053982
# 12                Partner                    CIPOLLA                10053982
# 13  Merch New Segmentaion                     NORMAL                10053982
# 14           Mens Grading                          L                10053982
# 15         Womens Grading                          M                10053982
# 16         SAP Store Name                   LS ARESE                10053982
# 17                  TOTAL                        379                10053982
# 18                IA PACK                    IT_PLUS                10057217
# 19            Ship to Key                   10057217                10057217
# 20            Index Store                          3                10057217
# 21                Partner                    CIPOLLA                10057217
# 22  Merch New Segmentaion                     NORMAL                10057217
# 23           Mens Grading                          M                10057217
# 24         Womens Grading                          M                10057217
# 25         SAP Store Name      LS ASSAGO MILANOFIORI                10057217
# 26                  TOTAL                        342                10057217
# 27                IA PACK                         IT                10056631
# 28            Ship to Key                   10056631                10056631
# 29            Index Store                          4                10056631
# ..                    ...                        ...                     ...
# 60         Womens Grading                          S                20055131
# 61         SAP Store Name              NEW COQUELLES                20055131
# 62                  TOTAL                        285                20055131
# 63                IA PACK                     FR_SKU                20058510
# 64            Ship to Key                   20058510                20058510
# 65            Index Store                         11                20058510
# 66                Partner                  BOURBOTTE                20058510
# 67  Merch New Segmentaion                     NORMAL                20058510
# 68           Mens Grading                          M                20058510
# 69         Womens Grading                          S                20058510
# 70         SAP Store Name  LS LUXEMBOURG CLOCHE D’OR                20058510
# 71                  TOTAL                        282                20058510
# 72                IA PACK                     FR_SKU                20060504
# 73            Ship to Key                   20060504                20060504
# 74            Index Store                         12                20060504
# 75                Partner                  BOURBOTTE                20060504
# 76  Merch New Segmentaion                     NORMAL                20060504
# 77           Mens Grading                          S                20060504
# 78         Womens Grading                          S                20060504
# 79         SAP Store Name               LS LILLENIUM                20060504
# 80                  TOTAL                        233                20060504
# 81                IA PACK                     FR_SKU  LS Nimes Cap Costières
# 82            Ship to Key     LS Nimes Cap Costières  LS Nimes Cap Costières
# 83            Index Store                         13  LS Nimes Cap Costières
# 84                Partner                  BOURBOTTE  LS Nimes Cap Costières
# 85  Merch New Segmentaion                     NORMAL  LS Nimes Cap Costières
# 86           Mens Grading                          M  LS Nimes Cap Costières
# 87         Womens Grading                          M  LS Nimes Cap Costières
# 88         SAP Store Name     LS NIMES CAP COSTIÈRES  LS Nimes Cap Costières
# 89                  TOTAL                        313  LS Nimes Cap Costières
#
#                     measure                         source_file
# 0   OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 1   OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 2   OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 3   OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 4   OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 5   OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 6   OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 7   OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 8   OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 9   OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 10  OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 11  OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 12  OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 13  OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 14  OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 15  OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 16  OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 17  OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 18  OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 19  OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 20  OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 21  OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 22  OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 23  OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 24  OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 25  OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 26  OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 27  OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 28  OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# 29  OPTIONS_CUSTOMER_REVIEW  ITALY FACTORY ASSORTMENT FW21.xlsx
# ..                      ...                                 ...
# 60  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 61  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 62  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 63  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 64  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 65  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 66  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 67  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 68  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 69  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 70  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 71  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 72  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 73  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 74  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 75  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 76  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 77  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 78  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 79  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 80  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 81  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 82  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 83  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 84  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 85  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 86  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 87  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 88  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
# 89  OPTIONS_CUSTOMER_REVIEW     01_FR_02_BOURBOTTE_APPAREL.xlsx
#
# [2205 rows x 5 columns]

# %%
timestr = time.strftime("%Y%m%d-%H%M%S")
file_name = "sl_output_gradings_IApack"+timestr+".xlsx"
print (file_name)
# Out:
# sl_output_gradings_IApack20201222-165052.xlsx

# %%
appended_data.to_excel(file_name)
